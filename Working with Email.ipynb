# %% [markdown]
# ## Sending the Email

# %%
import smtplib

# %%
smtp_object = smtplib.SMTP('smtp.gmail.com',587)

# %%
smtp_object.ehlo()
# Out:
# (250,
#  b'smtp.gmail.com at your service, [122.252.236.136]\nSIZE 35882577\n8BITMIME\nSTARTTLS\nENHANCEDSTATUSCODES\nPIPELINING\nCHUNKING\nSMTPUTF8')

# %%
smtp_object.starttls()
# Out:
# (220, b'2.0.0 Ready to start TLS')

# %%
import getpass

# %%
# password = getpass.getpass("Enter the Password: ")

# %%
email = getpass.getpass("e-Mail: ")
password = getpass.getpass("Enter the Password: ")
smtp_object.login(email,password)
# Out:
# e-Mail: ········
# Enter the Password: ········
# (235, b'2.7.0 Accepted')

# %%
email2 = "sandeep@creativetribe.in"
from_address = email
to_address = email2
subject = input("Enter the Subject: ")
body = input("Enter the body: ")
msg = "Subject: "+subject+"\n"+body

smtp_object.sendmail(from_address,to_address,msg)
# Out:
# Enter the Subject: Hey this Email is generated by python
# Enter the body: Hey I am a Bot of Python Programming!!
# {}
